# %% [markdown]
# # Retrieving artist data from Artsy API (json format, saved as json file)

# %%
import requests
import json

#CLIENT INFO UPON SIGNING UP FOR API
client_id = '02eec47d1e2db7f35ee6'
client_secret = '5e0be59fb0e02a34312e9848bcb29164'

# initiate the request to get the token 
r = requests.post("https://api.artsy.net/api/tokens/xapp_token",
                  data={
                      "client_id": client_id,
                      "client_secret": client_secret
                  })

# parse the server response 
j = json.loads(r.text)

# extract the token 
token = j["token"]

#inegrate token into url get requests
headers = {"X-Xapp-Token": token}

#testing to see if /artists/{id} will generate more artist ids
count_url = 'https://api.artsy.net/api/artists?cursor=valentien-anna%3A5a440757275b243650076056'
artist = requests.get(count_url, headers = headers)

#format json and load text
j3 = json.loads(artist.text)

# %%
#check format
artistdata = j3['_embedded']['artists']

print(artistdata)
# Out:
# [{'id': '5b8fe48385ab5c5f1ae98836', 'slug': 'anne-marie-valentien', 'created_at': '2018-09-05T14:13:23+00:00', 'updated_at': '2019-01-22T12:46:57+00:00', 'name': 'Anne Marie Valentien', 'sortable_name': 'Valentien Anne Marie', 'gender': None, 'biography': '', 'birthday': '', 'deathday': '', 'hometown': '', 'location': '', 'nationality': '', 'image_versions': ['square', 'four_thirds', 'tall', 'large'], '_links': {'thumbnail': {'href': 'https://d32dm0rphc51dk.cloudfront.net/-46DyjZmjuH11XEgO-bOYg/square.jpg'}, 'image': {'href': 'https://d32dm0rphc51dk.cloudfront.net/-46DyjZmjuH11XEgO-bOYg/{image_version}.jpg', 'templated': True}, 'self': {'href': 'https://api.artsy.net/api/artists/5b8fe48385ab5c5f1ae98836'}, 'permalink': {'href': 'https://www.artsy.net/artist/anne-marie-valentien'}, 'artworks': {'href': 'https://api.artsy.net/api/artworks?artist_id=5b8fe48385ab5c5f1ae98836'}, 'published_artworks': {'href': 'https://api.artsy.net/api/artworks?artist_id=5b8fe48385ab5c5f1ae98836&published
# ...

# %%
#Function 1: Next_URL
#function to assign href next url as the target url, save this new url

def nexturl(source):
    
    #assign value to next_url to target in next function
    next_url = source['_links']['next']['href']
    
    #give back this new URL to use in function to get new batch of artist information
    return next_url

# %%
#Function 2: Embedded Artist Info
#using the returned next_url, get data within url, reassign 'source' as data acquired from the get statement

def new_source(x):
    #assigning global to avoid local variable UnboundError
    global newsource
    global artistdata
    #use try and catch to except when artist.text is no longer in correct json format to load
    try: 
        #reassign source of data
        newsource = json.loads(x.text)
    
    #accounting for errors
    except json.decoder.JSONDecodeError as e:
        pass
        print('Data not in readable json format, error: ' + str(e))
        #print next url that breaks loop
        print(str(x))
    
    #return new source to target data in keys next
    return newsource

# %%
#reassign artist data to 

def artist_data(s):
    
    #make artistdata work outside scope of all functions
    global artistdata
    
    try:
        #assign new data to var
        newdata = s['_embedded']['artists']
        #update artistdata var with old and new data
        artistdata = artistdata + newdata
    #if value of keys doesnt exist
    except KeyError as e:
        #keep track of what it shows
        print(s['_links']['next']['href'])
        #print all source keys to examine
        print(s.keys())
    #return artist data to store
    return artistdata

# %%
import time


def get_info(source):
    """Function to first assign href next url as target url, save this url
    THEN use new target url to download items within 'artists' on each href next page
    do manually for first one"""
    #make sure value is assigned to href key, if True
    while source['_links']['next']['href']:
        try:
            #assign artist data to original list at base source
            artistdata = source['_embedded']['artists']
            
            #download next url for reference, assign url
            url = nexturl(source)
            artist = requests.get(url, headers = headers)
            
            #get data using that url, reassign source to new var
            loads = new_source(artist)
            
            #pass new data source to artist_data which updates artistdata to include data group
            #global data
            #data = artist_data(loads)
            
            with open('ArtistsALL.json', 'a') as outfile:
                for artist in loads['_embedded']['artists']:
                    outfile.write(json.dumps(artist) + '\n')
            #for each dict in data, append to list
            #returns length of artistdata to keep track of correct pagination
            
            #write to a file: options ... ?
                #rewrite the file each time function is called (clearning and writing each time - unreliable)
                #appending i in final_list to one list in file?
            try: #delay to loop through function with new source and do it over again
                time.sleep(0.5)
                info.append(get_info(loads))
            except RuntimeError:
                time.sleep(2)
                info.append(get_info(loads))
                pass
            
        #if next url doesnt exist
        except KeyError:
            print('No more links')
            
    return 'done'

# %%
get_info(j3)
# Out:
# Data not in readable json format, error: Expecting value: line 1 column 1 (char 0)
# <Response [502]>
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# No more links
# ...
